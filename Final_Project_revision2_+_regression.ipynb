# %%
import matplotlib.pyplot as plt
from pyspark.sql.functions import collect_list
from pyspark.sql.types import StructField, StructType, StringType, LongType
import pandas as pd
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
gcs_path = 'gs://pstat135-voter-file/VM2Uniform'

Iowa = spark.read.parquet("/".join([gcs_path, 'VM2Uniform--IA--2021-03-04']))

# %%
Iowa.printSchema()

# %%
# choose variables to include in dataframe 
Iowa_df = Iowa[['County',
             'Parties_Description',
             "Residence_Addresses_Property_LandSq_Footage",
             "Residence_Addresses_Property_HomeSq_Footage",
             "Voters_Gender",
             'CommercialData_Education',
             'CommercialData_EstimatedAreaMedianHHIncome',
             'CommercialData_EstimatedHHIncome',
             "CommercialData_AreaMedianHousingValue"]]

# transform to pandas dataframe 
Iowa_df = Iowa_df.toPandas()

# %%
# rename columns 
Iowa_df = Iowa_df.rename(columns = {"Residence_Addresses_Property_LandSq_Footage" : "Property_LandSq_Footage",
                                      "Residence_Addresses_Property_HomeSq_Footage" : "Property_HomeSq_Footage",
                                      "CommercialData_Education" : "Education",
                                      "CommercialData_AreaMedianEducationYears" : "AreaMedianEducationYears",
                                      "CommercialData_EstimatedAreaMedianHHIncome" : "EstimatedAreaMedianHHIncome",
                                      "CommercialData_EstimatedHHIncome" : "EstimatedHHIncome",
                                      "CommercialData_AreaMedianHousingValue" : "AreaMedianHousingValue"})
Iowa_df.head()
# Out:
#   County Parties_Description Property_LandSq_Footage Property_HomeSq_Footage  \
# 0  ADAIR          Democratic                 0342000                   03500
# 1  ADAIR        Non-Partisan                 0342000                   03500
# 2  ADAIR        Non-Partisan                 1698000                   01600
# 3  ADAIR        Non-Partisan                 0050000                   02300
# 4  ADAIR          Democratic                 1555000                   02800
#
#   Voters_Gender                       Education EstimatedAreaMedianHHIncome  \
# 0             F                            None                      $66266
# 1             M                            None                      $66266
# 2             F           Some College - Likely                      $66266
# 3             F  Bach Degree - Extremely Likely                      $66266
# 4             F             HS Diploma - Likely                      $69948
#
#   EstimatedHHIncome AreaMedianHousingValue
# 0      $50000-74999                $104166
# 1      $50000-74999                $104166
# 2      $50000-74999                $104166
# 3      $15000-24999                $104166
# 4      $75000-99999                 $91666

# %% [markdown]
# ## Data Cleaning

# %%
Iowa_clean = Iowa_df

# percentage of data missing for each variable
percent_missing = Iowa_df.isnull().sum() * 100 / len(Iowa_df)

percent_missing
# Out:
# County                          0.000000
# Parties_Description             0.000000
# Property_LandSq_Footage        16.660255
# Property_HomeSq_Footage        18.341540
# Voters_Gender                   0.000000
# Education                      29.684130
# EstimatedAreaMedianHHIncome     3.614241
# EstimatedHHIncome               2.586416
# AreaMedianHousingValue          3.619193
# dtype: float64

# %% [markdown]
#     The EstimatedAreaMedianHHIncome and EstimatedHHIncome and AreaMedianHousingValue variables have a very low proportion of missing values.We can proceed by changing the variable types from object to float and factor and proceed by filling in the data using the fillna method.

# %%
# remove dollar signs from estimated median household income and area median housing value and convert to numeric
Iowa_clean["EstimatedAreaMedianHHIncome"] = Iowa_clean["EstimatedAreaMedianHHIncome"].str.replace("$"," ")
Iowa_clean["AreaMedianHousingValue"] = Iowa_clean["AreaMedianHousingValue"].str.replace("$"," ")


# change types of variables 
Iowa_clean["EstimatedAreaMedianHHIncome"] = pd.to_numeric(Iowa_clean["EstimatedAreaMedianHHIncome"])
Iowa_clean["AreaMedianHousingValue"] = pd.to_numeric(Iowa_clean["AreaMedianHousingValue"])

# Change types of Education and EstimatedHHIncome variables 
CleanUp = {'Education':{
    np.nan: 1, 'Less than HS Diploma - Ex Like': 2, 'Less than HS Diploma - Likely': 3, 
    'HS Diploma - Likely': 4,'HS Diploma - Extremely Likely': 5, 
    'Vocational Technical Degree - Extremely Likely':5,
    'Some College - Likely': 6, 'Some College -Extremely Likely': 7, 
    'Bach Degree - Likely': 8, 'Bach Degree - Extremely Likely': 9, 'Grad Degree - Likely': 10, 
    'Grad Degree - Extremely Likely': 11
},

'EstimatedHHIncome':{
    '$1000-14999': 1, '$15000-24999': 2, '$25000-34999':3, '$35000-49999':4,
    '$50000-74999': 5, '$75000-99999': 6, '$100000-124999': 7, '$125000-149999': 8,
    '$150000-174999': 9, '$175000-199999': 10, '$200000-249999': 11, '$250000+': 12
}

}

Iowa_clean = Iowa_df.replace(CleanUp)

Iowa_clean.head()
# Out:
# /tmp/ipykernel_9809/3847562280.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   Iowa_clean["EstimatedAreaMedianHHIncome"] = Iowa_clean["EstimatedAreaMedianHHIncome"].str.replace("$"," ")
# /tmp/ipykernel_9809/3847562280.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   Iowa_clean["AreaMedianHousingValue"] = Iowa_clean["AreaMedianHousingValue"].str.replace("$"," ")
#   County Parties_Description Property_LandSq_Footage Property_HomeSq_Footage  \
# 0  ADAIR          Democratic                 0342000                   03500
# 1  ADAIR        Non-Partisan                 0342000                   03500
# 2  ADAIR        Non-Partisan                 1698000                   01600
# 3  ADAIR        Non-Partisan                 0050000                   02300
# 4  ADAIR          Democratic                 1555000                   02800
#
#   Voters_Gender  Education  EstimatedAreaMedianHHIncome  EstimatedHHIncome  \
# 0             F          1                      66266.0                5.0
# 1             M          1                      66266.0                5.0
# 2             F          6                      66266.0                5.0
# 3             F          9                      66266.0                2.0
# 4             F          4                      69948.0                6.0
#
#    AreaMedianHousingValue
# 0                104166.0
# 1                104166.0
# 2                104166.0
# 3                104166.0
# 4                 91666.0

# %%
# fill missing values with mean of each column
Iowa_clean["EstimatedAreaMedianHHIncome"] = Iowa_clean["EstimatedAreaMedianHHIncome"].fillna(Iowa_clean["EstimatedAreaMedianHHIncome"].mean())
Iowa_clean["AreaMedianHousingValue"] = Iowa_clean["AreaMedianHousingValue"].fillna(Iowa_clean["AreaMedianHousingValue"].mean())

# Fill EstimatedHHIncome using the median 
Iowa_clean["EstimatedHHIncome"] = Iowa_clean["EstimatedHHIncome"].fillna(Iowa_clean["EstimatedHHIncome"].median())

# %%
Iowa_clean.isnull().sum() * 100 / len(Iowa_clean)
# Out:
# County                          0.000000
# Parties_Description             0.000000
# Property_LandSq_Footage        16.660255
# Property_HomeSq_Footage        18.341540
# Voters_Gender                   0.000000
# Education                       0.000000
# EstimatedAreaMedianHHIncome     0.000000
# EstimatedHHIncome               0.000000
# AreaMedianHousingValue          0.000000
# dtype: float64

# %%
# Keep only the rows with at least 8 non-NA values.
Iowa_clean = Iowa_clean.dropna(thresh = 8)

# drop rows with missing values in EstimatedHouseholdIncome and Education

#Iowa_clean = Iowa_clean.dropna(subset = ["EstimatedHouseholdIncome","Education"],how = "all")
Iowa_clean.isnull().sum() * 100 / len(Iowa_clean)
# Out:
# County                         0.000000
# Parties_Description            0.000000
# Property_LandSq_Footage        1.104475
# Property_HomeSq_Footage        3.099580
# Voters_Gender                  0.000000
# Education                      0.000000
# EstimatedAreaMedianHHIncome    0.000000
# EstimatedHHIncome              0.000000
# AreaMedianHousingValue         0.000000
# dtype: float64

# %%
# Only 1.1% and 3.09% is missing for Land square footage and home square footage respectively so fill in with mean 
Iowa_clean["Property_LandSq_Footage"] = pd.to_numeric(Iowa_clean["Property_LandSq_Footage"])
Iowa_clean["Property_HomeSq_Footage"] = pd.to_numeric(Iowa_clean["Property_HomeSq_Footage"])

Iowa_clean["Property_LandSq_Footage"] = Iowa_clean["Property_LandSq_Footage"].fillna(Iowa_clean["Property_LandSq_Footage"].mean())
Iowa_clean["Property_HomeSq_Footage"] = Iowa_clean["Property_HomeSq_Footage"].fillna(Iowa_clean["Property_HomeSq_Footage"].mean())

Iowa_clean.isnull().sum() * 100 / len(Iowa_clean)
# Out:
# County                         0.0
# Parties_Description            0.0
# Property_LandSq_Footage        0.0
# Property_HomeSq_Footage        0.0
# Voters_Gender                  0.0
# Education                      0.0
# EstimatedAreaMedianHHIncome    0.0
# EstimatedHHIncome              0.0
# AreaMedianHousingValue         0.0
# dtype: float64

# %% [markdown]
#     Our dataset is now clean

# %% [markdown]
# ## Comparing Counties - Property Size

# %% [markdown]
#     In the following part of our analysis we will conduct a comparison of counties. The purpose of this comparison will be to identify different voting patterns in counties where voters have larger properties versus counties were voters have lower properties. As stated in our introduction it is our assumption that individuals with larger properties, like farmers, tend to lean toward the Republican party. The comparison will be based on the median property land square footage for each County.

# %%
# group by county and calculate median property square footage 

Iowa_grouped = Iowa_clean.groupby(by = ["County"]).aggregate({'Property_LandSq_Footage':'median'})

# Sort by descending order and reset index
Iowa_grouped = Iowa_grouped.sort_values(by = 'Property_LandSq_Footage', ascending = False).reset_index()

Iowa_grouped
# Out:
#          County  Property_LandSq_Footage
# 0      RINGGOLD                 489000.0
# 1       MADISON                 126000.0
# 2         DAVIS                  98000.0
# 3         ADAMS                  87000.0
# 4     VAN BUREN                  82000.0
# ..          ...                      ...
# 94         POLK                  10000.0
# 95   BLACK HAWK                  10000.0
# 96        SCOTT                   9000.0
# 97     WOODBURY                   9000.0
# 98  CERRO GORDO                   8000.0
#
# [99 rows x 2 columns]

# %%
# assign top 5 and bottom 5 county names
top = ["RINGGOLD", "MADISON", "VAN BUREN", "DAVIS", "ADAMS"]
bottom = ["POLK","BLACK HAWK","SCOTT", "CERRO GORDO","WOODBURY"]


#return top 5 and bottom 5 counties in terms of square footage from clean dataframe 
top5_df = Iowa_clean[Iowa_clean["County"].isin(top)].round(0)

bottom5_df = Iowa_clean[Iowa_clean["County"].isin(bottom)].round(0)

# %% [markdown]
#     We have now extracted the data for the top and bottom 5 counties in terms of property land square footage per voter. We proceed by creating a table containing the voting pattern for each group including the proportion of votes each party has acucumulated.

# %%
#Top 5 counties in land square footage voting patterns 

top5_voting_pattern = top5_df['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
top5_voting_pattern["Proportion"] = top5_voting_pattern["Parties_Description"] / top5_voting_pattern["Parties_Description"].sum()
top5_voting_pattern = top5_voting_pattern.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Top 5 Counties - Vote Counts")

top5_voting_pattern
# Out:
# <style  type="text/css" >
# </style><table id="T_c8ae5_" ><caption>Top 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c8ae5_level0_row0" class="row_heading level0 row0" >Republican</th>
#                         <td id="T_c8ae5_row0_col0" class="data row0 col0" >11163</td>
#                         <td id="T_c8ae5_row0_col1" class="data row0 col1" >0.468286</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row1" class="row_heading level0 row1" >Non-Partisan</th>
#                         <td id="T_c8ae5_row1_col0" class="data row1 col0" >7059</td>
#                         <td id="T_c8ae5_row1_col1" class="data row1 col1" >0.296124</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row2" class="row_heading level0 row2" >Democratic</th>
#                         <td id="T_c8ae5_row2_col0" class="data row2 col0" >5454</td>
#                         <td id="T_c8ae5_row2_col1" class="data row2 col1" >0.228794</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_c8ae5_row3_col0" class="data row3 col0" >132</td>
#                         <td id="T_c8ae5_row3_col1" class="data row3 col1" >0.005537</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_c8ae5_row4_col0" class="data row4 col0" >30</td>
#                         <td id="T_c8ae5_row4_col1" class="data row4 col1" >0.001258</td>
#             </tr>
#     </tbody></table>

# %%
# Bottom 5 counties in land square footage voting patterns 

bottom5_voting_pattern = bottom5_df['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
bottom5_voting_pattern["Proportion"] = bottom5_voting_pattern["Parties_Description"] / bottom5_voting_pattern["Parties_Description"].sum()
bottom5_voting_pattern = bottom5_voting_pattern.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Bottom 5 Counties - Vote Counts")

bottom5_voting_pattern
# Out:
# <style  type="text/css" >
# </style><table id="T_fac99_" ><caption>Bottom 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fac99_level0_row0" class="row_heading level0 row0" >Democratic</th>
#                         <td id="T_fac99_row0_col0" class="data row0 col0" >190742</td>
#                         <td id="T_fac99_row0_col1" class="data row0 col1" >0.378363</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row1" class="row_heading level0 row1" >Non-Partisan</th>
#                         <td id="T_fac99_row1_col0" class="data row1 col0" >157846</td>
#                         <td id="T_fac99_row1_col1" class="data row1 col1" >0.313109</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row2" class="row_heading level0 row2" >Republican</th>
#                         <td id="T_fac99_row2_col0" class="data row2 col0" >150854</td>
#                         <td id="T_fac99_row2_col1" class="data row2 col1" >0.299239</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_fac99_row3_col0" class="data row3 col0" >3749</td>
#                         <td id="T_fac99_row3_col1" class="data row3 col1" >0.007437</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_fac99_row4_col0" class="data row4 col0" >934</td>
#                         <td id="T_fac99_row4_col1" class="data row4 col1" >0.001853</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
#     When comparing the proportion of voters for the 5 counties with the largest property in terms of land square footage per voter with the bottom 5 counties in terms of land square footage per voter we see a difference in the prevailing party. For the top 5 counties 46% of total votes went to the Republican party and 22% went to the Democratic party whereas for the bottom 5 counties 37% went to the Democratic party and 29% went to the Republican party. This falls inline with our assumption that that individuals with larger properties, like farmers, tend to lean toward the Republican party. In addition to that, we also notice that the top 5 counties have a significantly lower ammount of total votes than the bottom 5 counties. This makes intuitive sense as smaller property sizes may point toward more densly populated regions and as a result more votes. The data above may suggest that people with larger property may be more inclined to vote Red (Republican).

# %% [markdown]
#  ## Comparing Counties - Home size

# %% [markdown]
#     The relation of property size to voter patterns has raised an interesting question, does home size have a relation to voting patterns as well?. To examine this question we proceed with a similar analysis with the one carried out above using median house size per county as our measure. We will compare the voting habits of the top 5 and bottom counties in terms of home size in square feet. It is our expectation that people with larger homes will tend to lean toward the Republican party as larger homes are an indication of greater wealth.

# %%
# group by county and calculate median property square footage 

Iowa_home = Iowa_clean.groupby(by = ["County"]).aggregate({'Property_HomeSq_Footage':'median'})

# Sort by descending order and reset index
Iowa_home = Iowa_home.sort_values(by = 'Property_HomeSq_Footage', ascending = False).reset_index()

Iowa_home
# Out:
#            County  Property_HomeSq_Footage
# 0        DELAWARE                   3100.0
# 1            LYON                   3000.0
# 2         DUBUQUE                   3000.0
# 3        PLYMOUTH                   3000.0
# 4       CHICKASAW                   2900.0
# ..            ...                      ...
# 94        HANCOCK                   1500.0
# 95         TAYLOR                   1500.0
# 96         MONROE                   1400.0
# 97  POTTAWATTAMIE                   1300.0
# 98       RINGGOLD                   1200.0
#
# [99 rows x 2 columns]

# %%
top_home = ["LYON","DELAWARE","PLYMOUTH", "CHICKASAW", "DUBUQUE"]
bottom_home = ["HANCOCK", "TAYLOR", "MONROE", "RINGGOLD", "POTTAWATTAMIE"]

#return top 5 and bottom 5 counties in terms of home square footage from clean dataframe 
top5_home = Iowa_clean[Iowa_clean["County"].isin(top_home)].round(0)

bottom5_home = Iowa_clean[Iowa_clean["County"].isin(bottom_home)].round(0)

# %% [markdown]
#     Now that we have extracted the top and bottom 5 Counties in terms of median home size in square feet, we proceed by creating a table containing the voting pattern for each group including the proportion of votes each party has acucumulated.

# %%
#Top 5 counties in home square footage voting patterns 

top5_votes = top5_home['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
top5_votes["Proportion"] = top5_votes["Parties_Description"] / top5_votes["Parties_Description"].sum()
top5_votes = top5_votes.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Top 5 Counties - Vote Counts")

top5_votes
# Out:
# <style  type="text/css" >
# </style><table id="T_11f8b_" ><caption>Top 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11f8b_level0_row0" class="row_heading level0 row0" >Republican</th>
#                         <td id="T_11f8b_row0_col0" class="data row0 col0" >37336</td>
#                         <td id="T_11f8b_row0_col1" class="data row0 col1" >0.389761</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row1" class="row_heading level0 row1" >Democratic</th>
#                         <td id="T_11f8b_row1_col0" class="data row1 col0" >29486</td>
#                         <td id="T_11f8b_row1_col1" class="data row1 col1" >0.307813</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row2" class="row_heading level0 row2" >Non-Partisan</th>
#                         <td id="T_11f8b_row2_col0" class="data row2 col0" >28333</td>
#                         <td id="T_11f8b_row2_col1" class="data row2 col1" >0.295776</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_11f8b_row3_col0" class="data row3 col0" >493</td>
#                         <td id="T_11f8b_row3_col1" class="data row3 col1" >0.005147</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_11f8b_row4_col0" class="data row4 col0" >144</td>
#                         <td id="T_11f8b_row4_col1" class="data row4 col1" >0.001503</td>
#             </tr>
#     </tbody></table>

# %%
# Bottom 5 counties in land square footage voting patterns 

bottom5_votes = bottom5_home['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
bottom5_votes["Proportion"] = bottom5_votes["Parties_Description"] / bottom5_votes["Parties_Description"].sum()
bottom5_votes = bottom5_votes.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Bottom 5 Counties - Vote Counts")

bottom5_votes
# Out:
# <style  type="text/css" >
# </style><table id="T_62211_" ><caption>Bottom 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62211_level0_row0" class="row_heading level0 row0" >Republican</th>
#                         <td id="T_62211_row0_col0" class="data row0 col0" >28786</td>
#                         <td id="T_62211_row0_col1" class="data row0 col1" >0.430220</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row1" class="row_heading level0 row1" >Non-Partisan</th>
#                         <td id="T_62211_row1_col0" class="data row1 col0" >20118</td>
#                         <td id="T_62211_row1_col1" class="data row1 col1" >0.300673</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row2" class="row_heading level0 row2" >Democratic</th>
#                         <td id="T_62211_row2_col0" class="data row2 col0" >17346</td>
#                         <td id="T_62211_row2_col1" class="data row2 col1" >0.259244</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_62211_row3_col0" class="data row3 col0" >510</td>
#                         <td id="T_62211_row3_col1" class="data row3 col1" >0.007622</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_62211_row4_col0" class="data row4 col0" >150</td>
#                         <td id="T_62211_row4_col1" class="data row4 col1" >0.002242</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
#     Contrary to our initial assumption house size does not seem to have a relationship to voting patterns. From the results above we can see that the bottom 5 counties in terms of median house square footage size actually have a bigger proportion of their population voting Republican than the top 5 counties.

# %% [markdown]
# ## Regression

# %%
# must make pandas df back into a spark df
Iowa_clean_sp = spark.createDataFrame(Iowa_clean) 
Iowa_clean_sp.repartition(numPartitions=10)
# Out:
# DataFrame[County: string, Parties_Description: string, Property_LandSq_Footage: double, Property_HomeSq_Footage: double, Voters_Gender: string, Education: bigint, EstimatedAreaMedianHHIncome: double, EstimatedHHIncome: double, AreaMedianHousingValue: double]

# %%
from pyspark.ml.feature import RFormula

supervised = RFormula(formula="Parties_Description ~ .")
fittedRF = supervised.fit(Iowa_clean_sp)
preparedDF = fittedRF.transform(Iowa_clean_sp) 
preparedDF.show(5, truncate = False)
# Out:
# 23/03/18 22:28:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 5 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 8 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 11 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 11:>                                                         (0 + 1) / 1]
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------+-----+
# |County|Parties_Description|Property_LandSq_Footage|Property_HomeSq_Footage|Voters_Gender|Education|EstimatedAreaMedianHHIncome|EstimatedHHIncome|AreaMedianHousingValue|features                                                                                |label|
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------+-----+
# |ADAIR |Democratic         |342000.0               |3500.0                 |F            |1        |66266.0                    |5.0              |104166.0              |(105,[86,98,99,100,101,102,103,104],[1.0,342000.0,3500.0,1.0,1.0,66266.0,5.0,104166.0]) |2.0  |
# |ADAIR |Non-Partisan       |342000.0               |3500.0                 |M            |1        |66266.0                    |5.0              |104166.0              |(105,[86,98,99,101,102,103,104],[1.0,342000.0,3500.0,1.0,66266.0,5.0,104166.0])         |1.0  |
# |ADAIR |Non-Partisan       |1698000.0              |1600.0                 |F            |6        |66266.0                    |5.0              |104166.0              |(105,[86,98,99,100,101,102,103,104],[1.0,1698000.0,1600.0,1.0,6.0,66266.0,5.0,104166.0])|1.0  |
# |ADAIR |Non-Partisan       |50000.0                |2300.0                 |F            |9        |66266.0                    |2.0              |104166.0              |(105,[86,98,99,100,101,102,103,104],[1.0,50000.0,2300.0,1.0,9.0,66266.0,2.0,104166.0])  |1.0  |
# |ADAIR |Democratic         |1555000.0              |2800.0                 |F            |4        |69948.0                    |6.0              |91666.0               |(105,[86,98,99,100,101,102,103,104],[1.0,1555000.0,2800.0,1.0,4.0,69948.0,6.0,91666.0]) |2.0  |
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------+-----+
# only showing top 5 rows

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder, CrossValidatorModel

Iowa_train, Iowa_test = preparedDF.randomSplit([0.7, 0.3], seed = 123)

# repartition the training and testing data to make it run smoother
Iowa_train.repartition(numPartitions=10)
Iowa_test.repartition(numPartitions=10)
# Out:
# DataFrame[County: string, Parties_Description: string, Property_LandSq_Footage: double, Property_HomeSq_Footage: double, Voters_Gender: string, Education: bigint, EstimatedAreaMedianHHIncome: double, EstimatedHHIncome: double, AreaMedianHousingValue: double, features: vector, label: double]

# %%
lr = LogisticRegression(labelCol="label", featuresCol="features")
params = ParamGridBuilder().build()
evaluator = BinaryClassificationEvaluator()
multi_evaluator = MulticlassClassificationEvaluator()

cv = CrossValidator(estimator=lr, estimatorParamMaps=params, evaluator=multi_evaluator, numFolds=5, seed=123)

cvModel = cv.fit(Iowa_train)
# Out:
# 23/03/18 22:29:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 12 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:44 WARN org.apache.spark.scheduler.TaskSetManager: Stage 13 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:47 WARN com.github.fommil.netlib.BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeSystemBLAS
# 23/03/18 22:29:47 WARN com.github.fommil.netlib.BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeRefBLAS
# 23/03/18 22:29:47 WARN org.apache.spark.scheduler.TaskSetManager: Stage 14 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:49 WARN org.apache.spark.scheduler.TaskSetManager: Stage 15 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:50 WARN org.apache.spark.scheduler.TaskSetManager: Stage 16 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:51 WARN org.apache.spark.scheduler.TaskSetManager: Stage 17 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:53 WARN org.apache.spark.scheduler.TaskSetManager: Stage 18 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:54 WARN org.apache.spark.scheduler.TaskSetManager: Stage 19 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 20 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:57 WARN org.apache.spark.scheduler.TaskSetManager: Stage 21 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 22 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:29:59 WARN org.apache.spark.scheduler.TaskSetManager: Stage 23 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 24 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 25 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 26 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 27 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:05 WARN org.apache.spark.scheduler.TaskSetManager: Stage 28 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 29 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 30 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 31 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 32 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 33 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 34 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 35 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 36 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 37 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 38 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:30
contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 674 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 675 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:02 WARN org.apache.spark.scheduler.TaskSetManager: Stage 676 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 677 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 678 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 679 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 680 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 681 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 682 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 683 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 684 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 685 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 686 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 687 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 688 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:17 WARN org.apache.spark.scheduler.TaskSetManager: Stage 689 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:19 WARN org.apache.spark.scheduler.TaskSetManager: Stage 690 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 691 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:21 WARN org.apache.spark.scheduler.TaskSetManager: Stage 692 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:22 WARN org.apache.spark.scheduler.TaskSetManager: Stage 693 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:24 WARN org.apache.spark.scheduler.TaskSetManager: Stage 694 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:25 WARN org.apache.spark.scheduler.TaskSetManager: Stage 695 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:26 WARN org.apache.spark.scheduler.TaskSetManager: Stage 696 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:27 WARN org.apache.spark.scheduler.TaskSetManager: Stage 697 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:28 WARN org.apache.spark.scheduler.TaskSetManager: Stage 698 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 22:44:29 WARN org.apache.spark.scheduler.TaskSetManager: Stage 699 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.

# %%
cvModel.avgMetrics
# Out:
# [0.4342885080812767]

# %%
cvModel.bestModel
# Out:
# LogisticRegressionModel: uid=LogisticRegression_ee732ddb1ea2, numClasses=5, numFeatures=105

# %%
predictions  = cvModel.transform(Iowa_test)

predictions.select("features", "label", "prediction", "rawPrediction").show(5)
# Out:
# 23/03/18 22:47:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 700 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 700:>                                                        (0 + 1) / 1]
# +--------------------+-----+----------+--------------------+
# |            features|label|prediction|       rawPrediction|
# +--------------------+-----+----------+--------------------+
# |(105,[86,98,99,10...|  2.0|       1.0|[2.25347025690327...|
# |(105,[86,98,99,10...|  2.0|       1.0|[2.42751037790429...|
# |(105,[86,98,99,10...|  2.0|       1.0|[2.03751002054428...|
# |(105,[86,98,99,10...|  2.0|       1.0|[2.34747901859326...|
# |(105,[86,98,99,10...|  2.0|       0.0|[2.61603879414111...|
# +--------------------+-----+----------+--------------------+
# only showing top 5 rows

# %%
print("RMSE = ", multi_evaluator.evaluate(predictions))
# Out:
# 23/03/18 22:47:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 701 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 701:============================>                            (1 + 1) / 2]
# RMSE =  0.4361110702670655

# %% [markdown]
# Considering that the RMSE we received for the training model was roughly 0.4343, the RMSE for the testing model being 0.4361 is very reasonable. It is still relatively close together

# %%
from pyspark.mllib.evaluation import MulticlassMetrics

cvPredLabel = predictions.select("label", "prediction")
cvMetrics = MulticlassMetrics(cvPredLabel.rdd.map(tuple))

print(cvMetrics.confusionMatrix().toArray())
# Out:
# 23/03/18 23:21:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 703 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/18 23:21:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 704 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 704:============================>                            (1 + 1) / 2]
# [[103168.  63413.  51777.]
#  [ 37233.  52353.  37336.]
#  [ 47651.  54270.  80401.]]

# %%
precision = cvMetrics.weightedPrecision
print(precision)
# Out:
# 0.4648209664480844

# %%
accuracy = cvMetrics.accuracy
print(accuracy)
# Out:
# 0.4435449453939737

# %%
# predictions to see what the model would predict
# we believe that people with more education, property, home footage, household income, etc. would more likely vote Republican so we will test that

republicanData = [("ADAIR", "Republican", 489000, 3100, "M", 11, 54400, 12, 87585)]
republcianDF = spark.createDataFrame(data = republicanData, schema = ["County", "Parties_Description", "Property_LandSq_Footage", "Property_HomeSq_Footage", "Voters_Gender", "Education", "EstimatedAreaMedianHHIncome", "EstimatedHHIncome", "AreaMedianHousingValue"])

republcianDF.show()
# Out:
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+
# |County|Parties_Description|Property_LandSq_Footage|Property_HomeSq_Footage|Voters_Gender|Education|EstimatedAreaMedianHHIncome|EstimatedHHIncome|AreaMedianHousingValue|
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+
# | ADAIR|         Republican|                 489000|                   3100|            M|       11|                      54400|               12|                 87585|
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+

# %%
# check to see what the model predicted when given these variables
# acquired them from the top counties based on property footage and home footage and highest value for education and household income

predictions.filter((predictions.EstimatedHHIncome == 12) & (predictions.Education == 11) & (predictions.Property_LandSq_Footage > 489000) & (predictions.Property_HomeSq_Footage > 3100)).show(5)
# Out:
# 23/03/18 23:56:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 717 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 717:>                                                        (0 + 1) / 1]
# +---------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+--------------------+-----+--------------------+--------------------+----------+
# |   County|Parties_Description|Property_LandSq_Footage|Property_HomeSq_Footage|Voters_Gender|Education|EstimatedAreaMedianHHIncome|EstimatedHHIncome|AreaMedianHousingValue|            features|label|       rawPrediction|         probability|prediction|
# +---------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+--------------------+-----+--------------------+--------------------+----------+
# |    ADAIR|         Democratic|              1467000.0|                 5200.0|            M|       11|                    70562.0|             12.0|              124456.0|(105,[86,98,99,10...|  2.0|[3.69029671270152...|[0.66414068645916...|       0.0|
# |ALLAMAKEE|         Democratic|              3484000.0|                 6700.0|            F|       11|                    59518.0|             12.0|              151499.0|(105,[56,98,99,10...|  2.0|[3.82827536742393...|[0.70962215518710...|       0.0|
# |  AUDUBON|         Republican|              1742000.0|                 4200.0|            F|       11|                    65155.0|             12.0|               85416.0|(105,[92,98,99,10...|  0.0|[3.45079925289391...|[0.63615847742275...|       0.0|
# |   BENTON|       Non-Partisan|              1238000.0|                 5900.0|            M|       11|                    89116.0|             12.0|              160510.0|(105,[24,98,99,10...|  1.0|[3.04570490012525...|[0.57746472090679...|       0.0|
# |    BOONE|         Democratic|              1698000.0|                 6600.0|            M|       11|                    84374.0|             12.0|              177424.0|(105,[22,98,99,10...|  2.0|[3.27289318120486...|[0.63728754361829...|       0.0|
# +---------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+--------------------+-----+--------------------+--------------------+----------+
# only showing top 5 rows

# %%
# want to see how the lowest would do 
# acquired from bottom counties

predictions.filter((predictions.EstimatedHHIncome == 1) & (predictions.Education == 1) & (predictions.Property_LandSq_Footage < 8000) & (predictions.Property_HomeSq_Footage < 1200)).show(5)
# Out:
# 23/03/19 00:00:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 719 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 719:>                                                        (0 + 1) / 1]
# +----------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+--------------------+-----+--------------------+--------------------+----------+
# |    County|Parties_Description|Property_LandSq_Footage|Property_HomeSq_Footage|Voters_Gender|Education|EstimatedAreaMedianHHIncome|EstimatedHHIncome|AreaMedianHousingValue|            features|label|       rawPrediction|         probability|prediction|
# +----------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+--------------------+-----+--------------------+--------------------+----------+
# |   AUDUBON|         Democratic|                 5000.0|                  700.0|            M|        1|                    76281.0|              1.0|               88570.0|(105,[92,98,99,10...|  2.0|[2.13023796475122...|[0.40686473173617...|       0.0|
# |    BENTON|       Non-Partisan|                 6000.0|                 1100.0|            M|        1|                    95149.0|              1.0|              180823.0|(105,[24,98,99,10...|  1.0|[1.63903353212364...|[0.29476792696261...|       1.0|
# |BLACK HAWK|         Democratic|                 6000.0|                  800.0|            F|        1|                    57565.0|              1.0|               89697.0|(105,[4,98,99,100...|  2.0|[0.98259742742234...|[0.14981833048530...|       2.0|
# |BLACK HAWK|         Democratic|                 6000.0|                 1000.0|            F|        1|                    71553.0|              1.0|              156451.0|(105,[4,98,99,100...|  2.0|[1.19086698441749...|[0.18093968545289...|       2.0|
# |BLACK HAWK|       Non-Partisan|                 3000.0|                 1100.0|            M|        1|                    49218.0|              1.0|               79443.0|(105,[4,98,99,101...|  1.0|[1.11489179467863...|[0.19213125040427...|       2.0|
# +----------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+--------------------+-----+--------------------+--------------------+----------+
# only showing top 5 rows

# %% [markdown]
# Based on these predictions, we can see that the model tends to find people that vote Republican tend to be people with more education, a higher household income, a higher property squared footage, and a higher home squared footage. It seems to be very reliable when predicting whether someone would vote Republican. On the other hand, the model does seem to find when people vote Democratic, but at a lower rate. It does seem to believe that it is usually people on the lower end of things, but will still get this mixed up in some cases.
#
# Overall, the model seems to show that it is likely that there is some relationship between the way people vote and their way of life where those with more money, education, and land seem to vote Republican, while those with less usually vote Democratic.
