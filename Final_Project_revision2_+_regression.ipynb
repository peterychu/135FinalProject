# %%
import matplotlib.pyplot as plt
from pyspark.sql.functions import collect_list
from pyspark.sql.types import StructField, StructType, StringType, LongType
import pandas as pd
import numpy as np

# %%
# Import dataframe 
Iowa = spark.read\
.format("csv")\
.option("header", "true")\
.option("nullValue", "NA")\
.option("delimiter", "\t")\
.option("inferSchema", "true")\
.load("gs://pstat135-mh-project/data/VM2Uniform--IA--2021-03-04/VM2Uniform--IA--2021-03-04.tab")

# %%
gcs_path = 'gs://pstat135-voter-file/VM2Uniform'

Iowa = spark.read.parquet("/".join([gcs_path, 'VM2Uniform--IA--2021-03-04']))

# %%
Iowa.printSchema()

# %%
# choose variables to include in dataframe 
Iowa_df = Iowa[['County',
             'Parties_Description',
             "Residence_Addresses_Property_LandSq_Footage",
             "Residence_Addresses_Property_HomeSq_Footage",
             "Voters_Gender",
             'CommercialData_Education',
             'CommercialData_EstimatedAreaMedianHHIncome',
             'CommercialData_EstimatedHHIncome',
             "CommercialData_AreaMedianHousingValue"]]

# transform to pandas dataframe 
Iowa_df = Iowa_df.toPandas()

# %%
# rename columns 
Iowa_df = Iowa_df.rename(columns = {"Residence_Addresses_Property_LandSq_Footage" : "Property_LandSq_Footage",
                                      "Residence_Addresses_Property_HomeSq_Footage" : "Property_HomeSq_Footage",
                                      "CommercialData_Education" : "Education",
                                      "CommercialData_AreaMedianEducationYears" : "AreaMedianEducationYears",
                                      "CommercialData_EstimatedAreaMedianHHIncome" : "EstimatedAreaMedianHHIncome",
                                      "CommercialData_EstimatedHHIncome" : "EstimatedHHIncome",
                                      "CommercialData_AreaMedianHousingValue" : "AreaMedianHousingValue"})
Iowa_df.head()
# Out:
#   County Parties_Description Property_LandSq_Footage Property_HomeSq_Footage  \
# 0  ADAIR          Democratic                 0342000                   03500
# 1  ADAIR        Non-Partisan                 0342000                   03500
# 2  ADAIR        Non-Partisan                 1698000                   01600
# 3  ADAIR        Non-Partisan                 0050000                   02300
# 4  ADAIR          Democratic                 1555000                   02800
#
#   Voters_Gender                       Education EstimatedAreaMedianHHIncome  \
# 0             F                            None                      $66266
# 1             M                            None                      $66266
# 2             F           Some College - Likely                      $66266
# 3             F  Bach Degree - Extremely Likely                      $66266
# 4             F             HS Diploma - Likely                      $69948
#
#   EstimatedHHIncome AreaMedianHousingValue
# 0      $50000-74999                $104166
# 1      $50000-74999                $104166
# 2      $50000-74999                $104166
# 3      $15000-24999                $104166
# 4      $75000-99999                 $91666

# %% [markdown]
# ## Data Cleaning

# %%
Iowa_clean = Iowa_df

# percentage of data missing for each variable
percent_missing = Iowa_df.isnull().sum() * 100 / len(Iowa_df)

percent_missing
# Out:
# County                          0.000000
# Parties_Description             0.000000
# Property_LandSq_Footage        16.660255
# Property_HomeSq_Footage        18.341540
# Voters_Gender                   0.000000
# Education                      29.684130
# EstimatedAreaMedianHHIncome     3.614241
# EstimatedHHIncome               2.586416
# AreaMedianHousingValue          3.619193
# dtype: float64

# %% [markdown]
#     The EstimatedAreaMedianHHIncome and EstimatedHHIncome and AreaMedianHousingValue variables have a very low proportion of missing values.We can proceed by changing the variable types from object to float and factor and proceed by filling in the data using the fillna method.

# %%
# remove dollar signs from estimated median household income and area median housing value and convert to numeric
Iowa_clean["EstimatedAreaMedianHHIncome"] = Iowa_clean["EstimatedAreaMedianHHIncome"].str.replace("$"," ")
Iowa_clean["AreaMedianHousingValue"] = Iowa_clean["AreaMedianHousingValue"].str.replace("$"," ")


# change types of variables 
Iowa_clean["EstimatedAreaMedianHHIncome"] = pd.to_numeric(Iowa_clean["EstimatedAreaMedianHHIncome"])
Iowa_clean["AreaMedianHousingValue"] = pd.to_numeric(Iowa_clean["AreaMedianHousingValue"])

# Change types of Education and EstimatedHHIncome variables 
CleanUp = {'Education':{
    np.nan: 1, 'Less than HS Diploma - Ex Like': 2, 'Less than HS Diploma - Likely': 3, 
    'HS Diploma - Likely': 4,'HS Diploma - Extremely Likely': 5, 
    'Vocational Technical Degree - Extremely Likely':5,
    'Some College - Likely': 6, 'Some College -Extremely Likely': 7, 
    'Bach Degree - Likely': 8, 'Bach Degree - Extremely Likely': 9, 'Grad Degree - Likely': 10, 
    'Grad Degree - Extremely Likely': 11
},

'EstimatedHHIncome':{
    '$1000-14999': 1, '$15000-24999': 2, '$25000-34999':3, '$35000-49999':4,
    '$50000-74999': 5, '$75000-99999': 6, '$100000-124999': 7, '$125000-149999': 8,
    '$150000-174999': 9, '$175000-199999': 10, '$200000-249999': 11, '$250000+': 12
}

}

Iowa_clean = Iowa_df.replace(CleanUp)

Iowa_clean.head()
# Out:
# /tmp/ipykernel_9891/3847562280.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   Iowa_clean["EstimatedAreaMedianHHIncome"] = Iowa_clean["EstimatedAreaMedianHHIncome"].str.replace("$"," ")
# /tmp/ipykernel_9891/3847562280.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   Iowa_clean["AreaMedianHousingValue"] = Iowa_clean["AreaMedianHousingValue"].str.replace("$"," ")
#   County Parties_Description Property_LandSq_Footage Property_HomeSq_Footage  \
# 0  ADAIR          Democratic                 0342000                   03500
# 1  ADAIR        Non-Partisan                 0342000                   03500
# 2  ADAIR        Non-Partisan                 1698000                   01600
# 3  ADAIR        Non-Partisan                 0050000                   02300
# 4  ADAIR          Democratic                 1555000                   02800
#
#   Voters_Gender  Education  EstimatedAreaMedianHHIncome  EstimatedHHIncome  \
# 0             F          1                      66266.0                5.0
# 1             M          1                      66266.0                5.0
# 2             F          6                      66266.0                5.0
# 3             F          9                      66266.0                2.0
# 4             F          4                      69948.0                6.0
#
#    AreaMedianHousingValue
# 0                104166.0
# 1                104166.0
# 2                104166.0
# 3                104166.0
# 4                 91666.0

# %%
# fill missing values with mean of each column
Iowa_clean["EstimatedAreaMedianHHIncome"] = Iowa_clean["EstimatedAreaMedianHHIncome"].fillna(Iowa_clean["EstimatedAreaMedianHHIncome"].mean())
Iowa_clean["AreaMedianHousingValue"] = Iowa_clean["AreaMedianHousingValue"].fillna(Iowa_clean["AreaMedianHousingValue"].mean())

# Fill EstimatedHHIncome using the median 
Iowa_clean["EstimatedHHIncome"] = Iowa_clean["EstimatedHHIncome"].fillna(Iowa_clean["EstimatedHHIncome"].median())

# %%
Iowa_clean.isnull().sum() * 100 / len(Iowa_clean)
# Out:
# County                          0.000000
# Parties_Description             0.000000
# Property_LandSq_Footage        16.660255
# Property_HomeSq_Footage        18.341540
# Voters_Gender                   0.000000
# Education                       0.000000
# EstimatedAreaMedianHHIncome     0.000000
# EstimatedHHIncome               0.000000
# AreaMedianHousingValue          0.000000
# dtype: float64

# %%
# Keep only the rows with at least 8 non-NA values.
Iowa_clean = Iowa_clean.dropna(thresh = 8)

# drop rows with missing values in EstimatedHouseholdIncome and Education

#Iowa_clean = Iowa_clean.dropna(subset = ["EstimatedHouseholdIncome","Education"],how = "all")
Iowa_clean.isnull().sum() * 100 / len(Iowa_clean)
# Out:
# County                         0.000000
# Parties_Description            0.000000
# Property_LandSq_Footage        1.104475
# Property_HomeSq_Footage        3.099580
# Voters_Gender                  0.000000
# Education                      0.000000
# EstimatedAreaMedianHHIncome    0.000000
# EstimatedHHIncome              0.000000
# AreaMedianHousingValue         0.000000
# dtype: float64

# %%
# Only 1.1% and 3.09% is missing for Land square footage and home square footage respectively so fill in with mean 
Iowa_clean["Property_LandSq_Footage"] = pd.to_numeric(Iowa_clean["Property_LandSq_Footage"])
Iowa_clean["Property_HomeSq_Footage"] = pd.to_numeric(Iowa_clean["Property_HomeSq_Footage"])

Iowa_clean["Property_LandSq_Footage"] = Iowa_clean["Property_LandSq_Footage"].fillna(Iowa_clean["Property_LandSq_Footage"].mean())
Iowa_clean["Property_HomeSq_Footage"] = Iowa_clean["Property_HomeSq_Footage"].fillna(Iowa_clean["Property_HomeSq_Footage"].mean())

Iowa_clean.isnull().sum() * 100 / len(Iowa_clean)
# Out:
# County                          object
# Parties_Description             object
# Property_LandSq_Footage        float64
# Property_HomeSq_Footage        float64
# Voters_Gender                   object
# Education                        int64
# EstimatedAreaMedianHHIncome    float64
# EstimatedHHIncome              float64
# AreaMedianHousingValue         float64
# dtype: object

# %% [markdown]
#     Our dataset is now clean

# %% [markdown]
# ## Comparing Counties - Property Size

# %% [markdown]
#     In the following part of our analysis we will conduct a comparison of counties. The purpose of this comparison will be to identify different voting patterns in counties where voters have larger properties versus counties were voters have lower properties. As stated in our introduction it is our assumption that individuals with larger properties, like farmers, tend to lean toward the Republican party. The comparison will be based on the median property land square footage for each County.

# %%
# group by county and calculate median property square footage 

Iowa_grouped = Iowa_clean.groupby(by = ["County"]).aggregate({'Property_LandSq_Footage':'median'})

# Sort by descending order and reset index
Iowa_grouped = Iowa_grouped.sort_values(by = 'Property_LandSq_Footage', ascending = False).reset_index()

Iowa_grouped
# Out:
#          County  Property_LandSq_Footage
# 0      RINGGOLD                 489000.0
# 1       MADISON                 126000.0
# 2         DAVIS                  98000.0
# 3         ADAMS                  87000.0
# 4     VAN BUREN                  82000.0
# ..          ...                      ...
# 94         POLK                  10000.0
# 95   BLACK HAWK                  10000.0
# 96        SCOTT                   9000.0
# 97     WOODBURY                   9000.0
# 98  CERRO GORDO                   8000.0
#
# [99 rows x 2 columns]

# %%
# assign top 5 and bottom 5 county names
top = ["RINGGOLD", "MADISON", "VAN BUREN", "DAVIS", "ADAMS"]
bottom = ["POLK","BLACK HAWK","SCOTT", "CERRO GORDO","WOODBURY"]


#return top 5 and bottom 5 counties in terms of square footage from clean dataframe 
top5_df = Iowa_clean[Iowa_clean["County"].isin(top)].round(0)

bottom5_df = Iowa_clean[Iowa_clean["County"].isin(bottom)].round(0)

# %% [markdown]
#     We have now extracted the data for the top and bottom 5 counties in terms of property land square footage per voter. We proceed by creating a table containing the voting pattern for each group including the proportion of votes each party has acucumulated.

# %%
#Top 5 counties in land square footage voting patterns 

top5_voting_pattern = top5_df['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
top5_voting_pattern["Proportion"] = top5_voting_pattern["Parties_Description"] / top5_voting_pattern["Parties_Description"].sum()
top5_voting_pattern = top5_voting_pattern.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Top 5 Counties - Vote Counts")

top5_voting_pattern
# Out:
# <style  type="text/css" >
# </style><table id="T_c8ae5_" ><caption>Top 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c8ae5_level0_row0" class="row_heading level0 row0" >Republican</th>
#                         <td id="T_c8ae5_row0_col0" class="data row0 col0" >11163</td>
#                         <td id="T_c8ae5_row0_col1" class="data row0 col1" >0.468286</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row1" class="row_heading level0 row1" >Non-Partisan</th>
#                         <td id="T_c8ae5_row1_col0" class="data row1 col0" >7059</td>
#                         <td id="T_c8ae5_row1_col1" class="data row1 col1" >0.296124</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row2" class="row_heading level0 row2" >Democratic</th>
#                         <td id="T_c8ae5_row2_col0" class="data row2 col0" >5454</td>
#                         <td id="T_c8ae5_row2_col1" class="data row2 col1" >0.228794</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_c8ae5_row3_col0" class="data row3 col0" >132</td>
#                         <td id="T_c8ae5_row3_col1" class="data row3 col1" >0.005537</td>
#             </tr>
#             <tr>
#                         <th id="T_c8ae5_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_c8ae5_row4_col0" class="data row4 col0" >30</td>
#                         <td id="T_c8ae5_row4_col1" class="data row4 col1" >0.001258</td>
#             </tr>
#     </tbody></table>

# %%
# Bottom 5 counties in land square footage voting patterns 

bottom5_voting_pattern = bottom5_df['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
bottom5_voting_pattern["Proportion"] = bottom5_voting_pattern["Parties_Description"] / bottom5_voting_pattern["Parties_Description"].sum()
bottom5_voting_pattern = bottom5_voting_pattern.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Bottom 5 Counties - Vote Counts")

bottom5_voting_pattern
# Out:
# <style  type="text/css" >
# </style><table id="T_fac99_" ><caption>Bottom 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fac99_level0_row0" class="row_heading level0 row0" >Democratic</th>
#                         <td id="T_fac99_row0_col0" class="data row0 col0" >190742</td>
#                         <td id="T_fac99_row0_col1" class="data row0 col1" >0.378363</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row1" class="row_heading level0 row1" >Non-Partisan</th>
#                         <td id="T_fac99_row1_col0" class="data row1 col0" >157846</td>
#                         <td id="T_fac99_row1_col1" class="data row1 col1" >0.313109</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row2" class="row_heading level0 row2" >Republican</th>
#                         <td id="T_fac99_row2_col0" class="data row2 col0" >150854</td>
#                         <td id="T_fac99_row2_col1" class="data row2 col1" >0.299239</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_fac99_row3_col0" class="data row3 col0" >3749</td>
#                         <td id="T_fac99_row3_col1" class="data row3 col1" >0.007437</td>
#             </tr>
#             <tr>
#                         <th id="T_fac99_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_fac99_row4_col0" class="data row4 col0" >934</td>
#                         <td id="T_fac99_row4_col1" class="data row4 col1" >0.001853</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
#     When comparing the proportion of voters for the 5 counties with the largest property in terms of land square footage per voter with the bottom 5 counties in terms of land square footage per voter we see a difference in the prevailing party. For the top 5 counties 46% of total votes went to the Republican party and 22% went to the Democratic party whereas for the bottom 5 counties 37% went to the Democratic party and 29% went to the Republican party. This falls inline with our assumption that that individuals with larger properties, like farmers, tend to lean toward the Republican party. In addition to that, we also notice that the top 5 counties have a significantly lower ammount of total votes than the bottom 5 counties. This makes intuitive sense as smaller property sizes may point toward more densly populated regions and as a result more votes. The data above may suggest that people with larger property may be more inclined to vote Red (Republican).

# %% [markdown]
#  ## Comparing Counties - Home size

# %% [markdown]
#     The relation of property size to voter patterns has raised an interesting question, does home size have a relation to voting patterns as well?. To examine this question we proceed with a similar analysis with the one carried out above using median house size per county as our measure. We will compare the voting habits of the top 5 and bottom counties in terms of home size in square feet. It is our expectation that people with larger homes will tend to lean toward the Republican party as larger homes are an indication of greater wealth.

# %%
# group by county and calculate median property square footage 

Iowa_home = Iowa_clean.groupby(by = ["County"]).aggregate({'Property_HomeSq_Footage':'median'})

# Sort by descending order and reset index
Iowa_home = Iowa_home.sort_values(by = 'Property_HomeSq_Footage', ascending = False).reset_index()

Iowa_home
# Out:
#            County  Property_HomeSq_Footage
# 0        DELAWARE                   3100.0
# 1            LYON                   3000.0
# 2         DUBUQUE                   3000.0
# 3        PLYMOUTH                   3000.0
# 4       CHICKASAW                   2900.0
# ..            ...                      ...
# 94        HANCOCK                   1500.0
# 95         TAYLOR                   1500.0
# 96         MONROE                   1400.0
# 97  POTTAWATTAMIE                   1300.0
# 98       RINGGOLD                   1200.0
#
# [99 rows x 2 columns]

# %%
top_home = ["LYON","DELAWARE","PLYMOUTH", "CHICKASAW", "DUBUQUE"]
bottom_home = ["HANCOCK", "TAYLOR", "MONROE", "RINGGOLD", "POTTAWATTAMIE"]

#return top 5 and bottom 5 counties in terms of home square footage from clean dataframe 
top5_home = Iowa_clean[Iowa_clean["County"].isin(top_home)].round(0)

bottom5_home = Iowa_clean[Iowa_clean["County"].isin(bottom_home)].round(0)

# %% [markdown]
#     Now that we have extracted the top and bottom 5 Counties in terms of median home size in square feet, we proceed by creating a table containing the voting pattern for each group including the proportion of votes each party has acucumulated.

# %%
#Top 5 counties in home square footage voting patterns 

top5_votes = top5_home['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
top5_votes["Proportion"] = top5_votes["Parties_Description"] / top5_votes["Parties_Description"].sum()
top5_votes = top5_votes.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Top 5 Counties - Vote Counts")

top5_votes
# Out:
# <style  type="text/css" >
# </style><table id="T_11f8b_" ><caption>Top 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11f8b_level0_row0" class="row_heading level0 row0" >Republican</th>
#                         <td id="T_11f8b_row0_col0" class="data row0 col0" >37336</td>
#                         <td id="T_11f8b_row0_col1" class="data row0 col1" >0.389761</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row1" class="row_heading level0 row1" >Democratic</th>
#                         <td id="T_11f8b_row1_col0" class="data row1 col0" >29486</td>
#                         <td id="T_11f8b_row1_col1" class="data row1 col1" >0.307813</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row2" class="row_heading level0 row2" >Non-Partisan</th>
#                         <td id="T_11f8b_row2_col0" class="data row2 col0" >28333</td>
#                         <td id="T_11f8b_row2_col1" class="data row2 col1" >0.295776</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_11f8b_row3_col0" class="data row3 col0" >493</td>
#                         <td id="T_11f8b_row3_col1" class="data row3 col1" >0.005147</td>
#             </tr>
#             <tr>
#                         <th id="T_11f8b_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_11f8b_row4_col0" class="data row4 col0" >144</td>
#                         <td id="T_11f8b_row4_col1" class="data row4 col1" >0.001503</td>
#             </tr>
#     </tbody></table>

# %%
# Bottom 5 counties in land square footage voting patterns 

bottom5_votes = bottom5_home['Parties_Description'].value_counts().to_frame()

# add a proportion column that indicates the proportion of votes for each party
bottom5_votes["Proportion"] = bottom5_votes["Parties_Description"] / bottom5_votes["Parties_Description"].sum()
bottom5_votes = bottom5_votes.rename(columns = {"Parties_Description" : "Number of Votes"}).style.set_caption("Bottom 5 Counties - Vote Counts")

bottom5_votes
# Out:
# <style  type="text/css" >
# </style><table id="T_62211_" ><caption>Bottom 5 Counties - Vote Counts</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Votes</th>        <th class="col_heading level0 col1" >Proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62211_level0_row0" class="row_heading level0 row0" >Republican</th>
#                         <td id="T_62211_row0_col0" class="data row0 col0" >28786</td>
#                         <td id="T_62211_row0_col1" class="data row0 col1" >0.430220</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row1" class="row_heading level0 row1" >Non-Partisan</th>
#                         <td id="T_62211_row1_col0" class="data row1 col0" >20118</td>
#                         <td id="T_62211_row1_col1" class="data row1 col1" >0.300673</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row2" class="row_heading level0 row2" >Democratic</th>
#                         <td id="T_62211_row2_col0" class="data row2 col0" >17346</td>
#                         <td id="T_62211_row2_col1" class="data row2 col1" >0.259244</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row3" class="row_heading level0 row3" >Libertarian</th>
#                         <td id="T_62211_row3_col0" class="data row3 col0" >510</td>
#                         <td id="T_62211_row3_col1" class="data row3 col1" >0.007622</td>
#             </tr>
#             <tr>
#                         <th id="T_62211_level0_row4" class="row_heading level0 row4" >Green</th>
#                         <td id="T_62211_row4_col0" class="data row4 col0" >150</td>
#                         <td id="T_62211_row4_col1" class="data row4 col1" >0.002242</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
#     Contrary to our initial assumption house size does not seem to have a relationship to voting patterns. From the results above we can see that the bottom 5 counties in terms of median house square footage size actually have a bigger proportion of their population voting Republican than the top 5 counties.

# %% [markdown]
# ## Regression

# %%
from pyspark.ml.feature import RFormula

# must make pandas df back into a spark df
Iowa_clean_sp = spark.createDataFrame(Iowa_clean) 

supervised = RFormula(formula="Parties_Description ~ .")
fittedRF = supervised.fit(Iowa_clean_sp)
preparedDF = fittedRF.transform(Iowa_clean_sp) 
preparedDF.show(5, truncate = False)
# Out:
# 23/03/16 21:12:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 260 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 21:12:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 263 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 21:12:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 266 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 21:12:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 269 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------+-----+
# |County|Parties_Description|Property_LandSq_Footage|Property_HomeSq_Footage|Voters_Gender|Education|EstimatedAreaMedianHHIncome|EstimatedHHIncome|AreaMedianHousingValue|features                                                                                |label|
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------+-----+
# |ADAIR |Democratic         |342000.0               |3500.0                 |F            |1        |66266.0                    |5.0              |104166.0              |(105,[86,98,99,100,101,102,103,104],[1.0,342000.0,3500.0,1.0,1.0,66266.0,5.0,104166.0]) |2.0  |
# |ADAIR |Non-Partisan       |342000.0               |3500.0                 |M            |1        |66266.0                    |5.0              |104166.0              |(105,[86,98,99,101,102,103,104],[1.0,342000.0,3500.0,1.0,66266.0,5.0,104166.0])         |1.0  |
# |ADAIR |Non-Partisan       |1698000.0              |1600.0                 |F            |6        |66266.0                    |5.0              |104166.0              |(105,[86,98,99,100,101,102,103,104],[1.0,1698000.0,1600.0,1.0,6.0,66266.0,5.0,104166.0])|1.0  |
# |ADAIR |Non-Partisan       |50000.0                |2300.0                 |F            |9        |66266.0                    |2.0              |104166.0              |(105,[86,98,99,100,101,102,103,104],[1.0,50000.0,2300.0,1.0,9.0,66266.0,2.0,104166.0])  |1.0  |
# |ADAIR |Democratic         |1555000.0              |2800.0                 |F            |4        |69948.0                    |6.0              |91666.0               |(105,[86,98,99,100,101,102,103,104],[1.0,1555000.0,2800.0,1.0,4.0,69948.0,6.0,91666.0]) |2.0  |
# +------+-------------------+-----------------------+-----------------------+-------------+---------+---------------------------+-----------------+----------------------+----------------------------------------------------------------------------------------+-----+
# only showing top 5 rows

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder, CrossValidatorModel

Iowa_train, Iowa_test = preparedDF.randomSplit([0.7, 0.3], seed = 123)

lr = LogisticRegression(labelCol="label", featuresCol="features")
lrModel = lr.fit(Iowa_train)

params = ParamGridBuilder().build()

evaluator = BinaryClassificationEvaluator()
multi_evaluator = MulticlassClassificationEvaluator()
cv = CrossValidator(estimator=lr, estimatorParamMaps=params, evaluator=multi_evaluator, numFolds=5, seed=123)

cvModel = cv.fit(Iowa_train)
# Out:
# 23/03/16 23:57:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1638 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1639 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:29 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1640 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1641 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:31 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1642 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:32 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1643 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:33 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1644 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:35 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1645 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:36 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1646 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:37 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1647 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1648 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:39 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1649 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:40 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1650 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:41 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1651 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:42 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1652 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:43 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1653 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:44 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1654 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:45 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1655 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1656 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:47 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1657 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:48 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1658 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:49 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1659 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:50 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1660 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:51 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1661 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:52 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1662 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:53 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1663 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:54 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1664 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1665 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:56 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1666 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:57 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1667 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1668 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:57:59 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1669 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1670 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1671 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:02 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1672 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1673 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1674 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:05 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1675 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1676 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1677 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1678 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1679 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1680 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1681 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1682 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1683 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1684 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1685 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1686 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:17 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1687 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1688 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:19 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1689 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1690 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:21 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1691 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:22 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1692 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:23 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1693 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:24 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1694 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:25 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1695 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:26 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1696 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:27 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1697 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:28 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1698 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:29 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1699 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1700 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:31 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1701 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:32 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1702 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:33 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1703 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:34 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1704 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:35 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1705 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:36 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1706 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:37 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1707 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1708 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:39 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1709 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:40 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1710 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:41 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1711 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:42 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1712 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:43 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1713 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:44 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1714 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:45 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1715 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1716 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:47 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1717 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:48 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1718 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:49 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1719 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:50 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1720 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:51 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1721 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:52 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1722 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:53 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1723 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:54 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1724 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1725 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:56 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1726 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:57 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1727 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1728 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:58:59 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1729 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1730 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1731 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:02 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1732 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1733 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1734 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:05 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1735 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1736 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1737 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1738 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1739 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1740 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1741 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1742 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1743 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1744 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1745 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:17 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1746 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1747 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:19 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1748 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1749 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:21 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1750 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:22 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1751 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:23 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1752 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:33 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1753 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:35 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1754 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:36 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1755 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:37 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1756 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1757 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:39 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1758 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:40 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1759 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:41 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1760 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:42 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1761 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:43 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1762 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:44 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1763 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:45 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1764 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:45 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1765 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1766 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:48 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1767 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:48 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1768 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:49 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1769 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:50 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1770 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:51 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1771 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:52 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1772 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:53 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1773 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:54 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1774 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1775 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:56 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1776 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:57 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1777 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1778 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1779 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/16 23:59:59 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1780 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1781 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1782 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:02 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1783 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1784 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1785 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:05 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1786 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1787 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1788 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1789 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1790 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1791 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1792 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1793 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1794 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1795 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1796 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1797 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1798 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:17 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1799 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1800 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1801 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:19 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1802 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1803 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:21 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1804 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:22 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1805 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:23 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1806 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:24 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1807 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:25 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1808 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:26 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1809 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:27 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1810 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:28 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1811 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:29 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1812 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1813 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1814 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:31 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1815 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:32 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1816 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:33 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1817 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:34 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1818 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:35 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1819 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:36 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1820 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:37 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1821 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1822 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1823 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:39 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1824 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:40 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1825 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:41 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1826 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:42 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1827 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:43 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1828 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:44 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1829 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:45 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1830 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1831 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1832 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:47 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1833 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:48 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1834 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:49 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1835 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:50 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1836 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:51 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1837 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:52 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1838 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:53 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1839 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:54 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1840 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1841 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1842 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:56 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1843 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:57 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1844 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1845 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:00:59 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1846 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1847 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1848 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:02 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1849 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1850 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1851 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:05 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1852 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1853 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1854 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1855 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1856 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1857 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1858 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1859 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1860 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1861 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1862 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1863 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1864 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:25 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1866 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:34 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1867 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:36 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1868 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:37 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1869 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1870 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:39 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1871 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:40 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1872 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:41 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1873 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:42 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1874 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:43 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1875 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:44 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1876 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:45 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1877 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1878 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1879 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:47 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1880 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:48 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1881 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:49 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1882 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:50 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1883 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:51 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1884 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:52 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1885 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:53 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1886 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:54 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1887 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1888 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1889 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:56 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1890 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:57 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1891 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1892 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:01:59 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1893 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1894 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1895 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:02 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1896 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1897 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1898 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:05 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1899 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1900 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:07 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1901 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1902 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1903 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1904 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1905 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1906 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1907 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1908 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1909 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1910 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1911 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:17 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1912 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1913 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1914 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:19 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1915 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1916 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:02:21 WARN org.apache.spark.scheduler.TaskSetManager: Stage 1917 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# ...
# 23/03/17 00:10:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2347 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2348 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2349 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2350 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2351 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2352 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2353 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2354 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:17 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2355 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2356 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:19 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2357 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2358 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:21 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2359 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:22 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2360 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:23 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2361 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:24 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2362 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:25 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2363 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:26 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2364 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:27 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2365 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:28 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2366 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:29 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2367 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2368 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:31 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2369 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:32 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2370 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:33 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2371 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:34 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2372 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:35 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2373 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:36 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2374 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:37 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2375 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2376 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:39 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2377 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:40 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2378 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:41 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2379 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:42 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2380 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:43 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2381 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:44 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2382 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:45 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2383 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:46 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2384 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:47 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2385 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:48 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2386 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:49 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2387 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:50 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2388 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:51 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2389 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:52 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2390 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:53 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2391 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:54 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2392 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:55 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2393 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:56 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2394 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:57 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2395 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:58 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2396 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:10:59 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2397 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:00 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2398 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:01 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2399 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:02 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2400 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:03 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2401 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:04 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2402 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:05 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2403 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:06 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2404 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:08 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2405 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:09 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2406 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:10 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2407 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:11 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2408 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:12 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2409 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:13 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2410 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:14 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2411 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:15 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2412 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:16 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2413 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:17 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2414 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:18 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2415 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:19 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2416 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:20 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2417 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:21 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2418 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:22 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2419 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:23 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2420 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:24 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2421 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:25 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2422 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:26 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2423 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:27 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2424 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:28 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2425 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:29 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2426 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:30 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2427 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:31 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2428 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:32 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2429 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:33 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2430 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:34 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2431 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:35 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2432 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:37 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2433 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2434 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:38 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2435 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:40 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2436 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:41 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2437 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:42 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2438 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# 23/03/17 00:11:43 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2439 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.

# %%
cvModel.avgMetrics
# Out:
# [0.4342885080812767]

# %%
cvModel.bestModel
# Out:
# LogisticRegressionModel: uid=LogisticRegression_870ec00b88ef, numClasses=5, numFeatures=105

# %%
cvModel.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 cvModel.summary
#
# AttributeError: 'CrossValidatorModel' object has no attribute 'summary'

# %%
predictions  = cvModel.transform(Iowa_test)

fittedTest.select("features", "label", "prediction", "rawPrediction").show(5)
# Out:
# 23/03/17 01:25:56 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2452 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 2452:>                                                       (0 + 1) / 1]
# +--------------------+-----+----------+--------------------+
# |            features|label|prediction|       rawPrediction|
# +--------------------+-----+----------+--------------------+
# |(105,[86,98,99,10...|  2.0|       1.0|[2.25347025690327...|
# |(105,[86,98,99,10...|  2.0|       1.0|[2.42751037790429...|
# |(105,[86,98,99,10...|  2.0|       1.0|[2.03751002054428...|
# |(105,[86,98,99,10...|  2.0|       1.0|[2.34747901859326...|
# |(105,[86,98,99,10...|  2.0|       0.0|[2.61603879414111...|
# +--------------------+-----+----------+--------------------+
# only showing top 5 rows

# %%
print("RMSE = ", multi_evaluator.evaluate(predictions))
# Out:
# 23/03/17 01:08:22 WARN org.apache.spark.scheduler.TaskSetManager: Stage 2444 contains a task of very large size (65579 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 2444:============================>                           (1 + 1) / 2]
# RMSE =  0.4361110702670655

# %% [markdown]
# Considering that the RMSE we received for the training model was roughly 0.4343, the RMSE for the testing model being 0.4361 is very reasonable. It is still relatively close together
